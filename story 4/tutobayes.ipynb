# %% [markdown]
# # **creation de l'ensemble de données**

# %%
from sklearn.datasets import make_classification

X, y = make_classification(
    n_features=6,
    n_classes=3,
    n_samples=800,
    n_informative=2,
    random_state=1,
    n_clusters_per_class=1,
)
ex=X.shape
print(ex)
# Out:
# (800, 6)

# %% [markdown]
# # **uriliser scatter**

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1], c=y, marker="."); 
# c=y color les pts selon la classe cmap couleur de la carte s=taille des points

# %%
plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], c=y, cmap="plasma", s=10) # cmap couleur de la carte s=taille des points
plt.xlabel("Feature 1 (informative)")
plt.ylabel("Feature 2 (informative)")
plt.title("Visualisation des données (2 features informatives)")
plt.show()

# %% [markdown]
# # **separation du jeu de donées**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=125
)
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
# [[ 0.80003859 -1.51540611  1.43084338  1.70243005  0.06248819  0.33491514]
#  [-1.23508884  1.83587263 -1.27042094  0.04231678  0.23455151 -0.68473971]
#  [ 0.38490477 -0.8562306   0.92536051 -0.29708742  0.11364625 -0.22542008]
#  ...
#  [ 0.3213152  -0.06039709 -0.44701854 -0.89687959 -0.33526347 -0.41787062]
#  [ 1.13583636 -0.69853502 -0.67628021 -0.01309541 -0.86632102  1.08395198]
#  [ 0.2125531   0.83650191 -1.92907536 -0.75683724 -0.79789068 -0.77993812]]
# [[ 1.28246375e+00 -1.38932492e+00  3.55727261e-01  4.32790200e-01
#   -5.83360695e-01  1.64859408e+00]
#  [ 9.36019601e-01 -2.89000779e-01 -1.09150749e+00  5.23390285e-01
#   -9.02336485e-01 -2.58223480e+00]
#  [-2.46992130e+00  3.98202762e+00 -3.11953284e+00 -1.31758204e+00
#    2.64849347e-01 -4.09431262e-01]
#  ...
#  [ 7.82181988e-01 -1.38278251e+00  1.21478258e+00 -9.01693171e-02
#   -3.84979787e-03  1.35756648e+00]
#  [ 1.32327650e+00 -1.19108184e-01 -2.08253398e+00  9.31194711e-01
# ...

# %% [markdown]
# # **contrusction de model et formation**

# %%
from sklearn.naive_bayes import GaussianNB

# Build a Gaussian Classifier
model = GaussianNB()

# Model training
model.fit(X_train, y_train)

# Predict Output
predicted = model.predict([X_test[25]])

print("Actual Value:", y_test[25])
print("Predicted Value:", predicted[0])
# Out:
# Actual Value: 2
# Predicted Value: 2

# %% [markdown]
# # **evalutaion du model**

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
)

y_pred = model.predict(X_test)
accuray = accuracy_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test, average="weighted")

print("Accuracy:", accuray)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.8484848484848485
# F1 Score: 0.8491119695890328

# %% [markdown]
# # **matrice de confusion**

# %%
labels = [0,1,2]
cm = confusion_matrix(y_test, y_pred, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot();

# %% [markdown]
# # **chargement des données**

# %%
import pandas as pd


df = pd.read_csv('loan_data.csv')
df.head()
