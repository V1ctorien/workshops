# %%
scrapy startproject WebCrawler

# dans le terminal pour creer le projey scrapy

# %%
# toujour dans le terminall faire avec URL=.......

scrapy shell URL 

# cela lance le programme ( shell) de scrapy en ligne de commande

# %%
# récupérer le premier titre

#xpath method 
sub = response.css('div.js-categories-seasonal tr ~ tr')[0]
title = sub.xpath('//a[@class="hoverinfo_trigger fw-b"]/strong/text()').extract_first().strip()
print(title) 


#css method
title = sub.css('a[id] strong::text').extract_first().strip()
print(title)

# %%
# ajouter dans settings.py la ligne pour faire semblant que on est pas un robot lors de scraping  
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36'

# %%
 scrapy crawl Manga -o output.json --loglevel=DEBUG   #la commande de lancement du manga
